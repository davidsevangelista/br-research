# %%
ls
# Out:
# Untitled.ipynb                   market_features.py
# __pycache__/                     plot_lob_trades_volume_prop.eps
# cancellations_one_day.p          test.py
# fetcher_br_data.py               trades_one_day.p
# lob_1_one_day.p

# %%
run market_features.py

# %%
gr=imbalance_regime(lob,trades)
# Out:
# /Users/evanged/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
#gr2=gr
#gr2.columns=gr2.columns.droplevel()
pandas_df_to_markdown_table(gr)
# Out:
# Num|Mean|Num|Mean|Num|Mean
# ---|---|---|---|---|---
# 357|-0.7556096501105587|535|-0.7898887863981311|892.0|-0.772749218254345
# 464|-0.3921624231455792|519|-0.3901890803545446|983.0|-0.3911757517500619
# 493|0.005624906282225414|477|-0.015989707340869602|970.0|-0.005182400529322094
# 543|0.37914547941327914|447|0.3696459226077055|990.0|0.37439570101049235
# 555|0.7820630216686107|378|0.7684560721856627|933.0|0.7752595469271367

# %%
pandas_df_to_markdown_table(gr2)
# Out:
# Num|Mean|Num|Mean|Num|Mean
# ---|---|---|---|---|---
# 357|-0.7556096501105587|535|-0.7898887863981311|892.0|-0.772749218254345
# 464|-0.3921624231455792|519|-0.3901890803545446|983.0|-0.3911757517500619
# 493|0.005624906282225414|477|-0.015989707340869602|970.0|-0.005182400529322094
# 543|0.37914547941327914|447|0.3696459226077055|990.0|0.37439570101049235
# 555|0.7820630216686107|378|0.7684560721856627|933.0|0.7752595469271367

# %%
gr=imbalance_regime(lob,trades)
# Out:
# /Users/evanged/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
gr
# Out:
#          Imbalance Buy MO           Imbalance Sell MO            \
#                       Num      Mean               Num      Mean
# Regime
# Regime 1              357 -0.755610               535 -0.789889
# Regime 2              464 -0.392162               519 -0.390189
# Regime 3              493  0.005625               477 -0.015990
# Regime 4              543  0.379145               447  0.369646
# Regime 5              555  0.782063               378  0.768456
#
#          Total Imbalance
#                      Num      Mean
# Regime
# Regime 1           892.0 -0.772749
# Regime 2           983.0 -0.391176
# Regime 3           970.0 -0.005182
# Regime 4           990.0  0.374396
# Regime 5           933.0  0.775260

# %%
gr.iloc[:,gr.columns.get_level_values(1)=='Num'].transform(lambda x: x/x.sum())
# Out:
#          Imbalance Buy MO Imbalance Sell MO Total Imbalance
#                       Num               Num             Num
# Regime
# Regime 1         0.148010          0.227080        0.187081
# Regime 2         0.192371          0.220289        0.206166
# Regime 3         0.204395          0.202462        0.203440
# Regime 4         0.225124          0.189728        0.207634
# Regime 5         0.230100          0.160441        0.195680

# %%
grm=gr.iloc[:,gr.columns.get_level_values(1)=='Mean'].transform(lambda x: x/x.sum())

# %%
gr.columns.droplevel(1)
# Out:
# Index(['Imbalance Buy MO', 'Imbalance Buy MO', 'Imbalance Sell MO',
#        'Imbalance Sell MO', 'Total Imbalance', 'Total Imbalance'],
#       dtype='object')
